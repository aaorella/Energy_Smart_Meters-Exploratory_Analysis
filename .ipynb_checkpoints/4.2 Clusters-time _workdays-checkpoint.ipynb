# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from math import sqrt

# %%
dir_origen_csv = "./CSV_generated/"
dir_export = "./Images_generated/"

# %%
def DTWDistance(s1, s2):
    DTW={}
    
    for i in range(len(s1)):
        DTW[(i, -1)] = float('inf')
    for i in range(len(s2)):
        DTW[(-1, i)] = float('inf')
    DTW[(-1, -1)] = 0

    for i in range(len(s1)):
        for j in range(len(s2)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])
    return sqrt(DTW[len(s1)-1, len(s2)-1])

# %%
def DTWDistance(s1, s2,w):
    DTW={}
    
    w = max(w, abs(len(s1)-len(s2)))
    
    for i in range(-1,len(s1)):
        for j in range(-1,len(s2)):
            DTW[(i, j)] = float('inf')
    DTW[(-1, -1)] = 0
  
    for i in range(len(s1)):
        for j in range(max(0, i-w), min(len(s2), i+w)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])
    return sqrt(DTW[len(s1)-1, len(s2)-1])

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return sqrt(LB_sum)

# %%
df = pd.read_csv(dir_origen_csv + "sera.csv", low_memory = False, sep=",")
df["fecha"] =  pd.to_datetime(df["fecha"]) #transforming "fecha" to datetime
df
# Out:
#                     fecha   medidor  lectura_id_orig  voltajeA  voltajeB  \
# 0     2019-04-04 06:28:44  15029835          1142597  131.1979  127.9215
# 1     2019-04-04 08:28:44  15029835          1143023  128.4270  127.4788
# 2     2019-04-04 10:28:44  15029835          1143417  125.9862  125.7077
# 3     2019-04-04 12:28:45  15029835          1143779  126.8655  126.0735
# 4     2019-04-04 14:28:45  15029835          1144165  125.2453  123.8318
# 5     2019-04-04 16:28:45  15029835          1144530  125.9855  125.0129
# 6     2019-04-04 18:28:45  15029835          1144934  123.8179  122.0391
# 7     2019-04-05 06:28:47  15029835          1147537  129.0491  127.8222
# 8     2019-04-05 08:28:47  15029835          1147941  127.9209  127.1520
# 9     2019-04-05 10:28:48  15029835          1148346  126.8511  126.2283
# 10    2019-04-05 12:55:05  15029835          1148711  125.7741  124.2303
# 11    2019-04-05 19:20:18  15029835          1150332  124.7676  123.2557
# 12    2019-04-06 07:20:20  15029835          1152810  130.0819  128.8673
# 13    2019-04-06 09:20:20  15029835          1153179  125.6793  124.9557
# 14    2019-04-06 11:20:21  15029835          1153522  125.3778  124.4315
# 15    2019-04-06 13:20:21  15029835          1153857  125.2976  124.0304
# 16    2019-04-06 15:20:22  15029835          1154211  124.9318  123.6106
# 17    2019-04-06 17:20:22  15029835          1154536  127.5107  125.6685
# 18    2019-04-06 19:20:22  15029835          1154919  122.7861  120.8296
# 19    2019-04-07 07:20:24  15029835          1157382  131.4581  130.3194
# 20    2019-04-07 09:20:24  15029835          1157769  127.3224  125.5084
# 21    2019-04-07 11:20:24  15029835          1158125  126.7485  125.2830
# 22    2019-04-07 13:20:25  15029835          1158473  126.3136  124.8548
# 23    2019-04-07 15:20:25  15029835          1158854  125.3405  123.9477
# 24    2019-04-07 17:20:27  15029835          1159226  127.8652  125.9165
# 25    2019-04-07 19:20:25  15029835          1159641  123.3620  121.6635
# 20935  125.4000      0.9000      0.0000      0.8000   KV2C  ...  -79.5300
# 20936  125.3000      0.9000      0.0000      0.8000   KV2C  ...  -79.5300
# 20937  123.1000      1.4000      0.0000      1.4000   KV2C  ...  -79.5300
# 20938  125.7000      0.9000      0.0000      0.8000   KV2C  ...  -79.5300
# 20939  125.1000      1.3000      0.0000      1.3000   KV2C  ...  -79.5300
# 20940  123.9000      0.8000      0.0000      0.8000   KV2C  ...  -79.5300
# 20941  125.3000      0.1000      0.0000      0.9000   KV2C  ...  -79.5300
# 20942  125.1000      0.9000      0.0000      0.7000   KV2C  ...  -79.5300
# 20943  123.8000      0.9000      0.0000      0.8000   KV2C  ...  -79.5300
# 20944  124.5000      0.9000      0.0000      0.9000   KV2C  ...  -79.5300
# 20945  125.2000      0.9000      0.0000      0.7000   KV2C  ...  -79.5300
# 20946  124.1000      0.8000      0.0000      0.9000   KV2C  ...  -79.5300
# 20947  125.8000      0.9000      0.0000      0.9000   KV2C  ...  -79.5300
#
#        CLASIFICACION  kwh_consumido  kvarh_consumido  tipo_consumo  \
# 0            IGLESIA         0.4500           0.0000          bajo
# 1            IGLESIA         0.1830           0.0090          bajo
# 2            IGLESIA         0.0960           0.0000          bajo
# 3            IGLESIA         0.0960           0.0000          bajo
# 4            IGLESIA         0.1230           0.0000          bajo
# 5            IGLESIA         0.2490           0.0000          bajo
# 6            IGLESIA         0.1440           0.0000          bajo
# 7            IGLESIA         0.4470           0.0000          bajo
# 8            IGLESIA         0.1650           0.0120          bajo
# 9            IGLESIA         0.0930           0.0000          bajo
# 10           IGLESIA         0.0720           0.0000          bajo
# 11           IGLESIA         1.3170           0.0120          bajo
# 12           IGLESIA         0.3270           0.0000          bajo
# 13           IGLESIA         9.3660           6.0570          bajo
# 14           IGLESIA        31.8270          18.8760          bajo
# 15           IGLESIA        21.0000          10.8240          bajo
# 16           IGLESIA        41.4510          18.5730          bajo
# 17           IGLESIA         8.7750           0.6030          bajo
# 18           IGLESIA         5.3190           0.0000          bajo
# 19           IGLESIA         4.0290           0.0000          bajo
# 20           IGLESIA         5.0430           0.6450          bajo
# 21           IGLESIA        25.3800          12.3720          bajo
# 22           IGLESIA        18.7080          11.3580          bajo
# 23           IGLESIA         4.1880           2.1690          bajo
# 24           IGLESIA        19.5480          11.8500          bajo
# 25           IGLESIA         0.2730           0.0090          bajo
# 26           IGLESIA         0.3210           0.0000          bajo
# 27           IGLESIA         0.0960           0.0000          bajo
# 28           IGLESIA         0.0930           0.0000          bajo
# 29           IGLESIA         0.0930           0.0000          bajo
# ...              ...            ...              ...           ...
# 20918       FARMACIA        36.2723           6.4089         medio
# 20919       FARMACIA        23.5552           5.4946         medio
# 20920       FARMACIA        37.0777           6.1404         medio
# 20921       FARMACIA        39.5271           6.5180         medio
# 20922       FARMACIA        22.9177           6.1153         medio
# 20923       FARMACIA        36.7756           6.6647         medio
# 20924       FARMACIA        47.9493           8.7913         medio
# 20925       FARMACIA        23.9914           5.9643         medio
# 20926       FARMACIA        34.1920           6.3796         medio
# 20927       FARMACIA        36.5408           6.9793         medio
# 20928       FARMACIA        24.7967           5.9727         medio
# 20929       FARMACIA        34.8966           6.1908         medio
# 20930       FARMACIA        23.0855           5.5197         medio
# 20931       FARMACIA        34.5610           5.7756         medio
# 20932       FARMACIA        36.6415           6.3585         medio
# 20933       FARMACIA        23.8237           6.1405         medio
# 20934       FARMACIA        32.6484           6.2621         medio
# 20935       FARMACIA        34.4269           6.6773         medio
# 20936       FARMACIA        23.3874           5.4694         medio
# 20937       FARMACIA        40.2318           7.0884         medio
# 20938       FARMACIA        42.3121           8.5773         medio
# 20939       FARMACIA        23.4210           5.8762         medio
# 20940       FARMACIA        48.2177           9.0345         medio
# 20941       FARMACIA        37.5138           6.4257         medio
# 20942       FARMACIA        22.9848           5.8888         medio
# 20943       FARMACIA        34.7959           6.2537         medio
# 20944       FARMACIA        36.3059           6.5683         medio
# 20945       FARMACIA        25.5685           5.7000         medio
# 20946       FARMACIA        40.7015           7.4868         medio
# 20947       FARMACIA        26.2731           5.1255         medio
#
#        clasificacion_encoded  modelo_encoded  tipo_consumo_encoded   kwh_hora  \
# 0                          7               0                     0   0.225000
# 1                          7               0                     0   0.091500
# 2                          7               0                     0   0.048000
# 3                          7               0                     0   0.047993
# 4                          7               0                     0   0.061500
# 5                          7               0                     0   0.124500
# 6                          7               0                     0   0.072000
# 7                          7               0                     0   0.223500
# 8                          7               0                     0   0.082500
# 9                          7               0                     0   0.046494
# 10                         7               0                     0   0.029532
# 11                         7               0                     0   0.205131
# 12                         7               0                     0   0.163500
# 13                         7               0                     0   4.683000
# 14                         7               0                     0  15.911290
# 15                         7               0                     0  10.500000
# 16                         7               0                     0  20.722622
# 17                         7               0                     0   4.387500
# 18                         7               0                     0   2.659500
# 19                         7               0                     0   2.014500
# 20                         7               0                     0   2.521500
# 21                         7               0                     0  12.690000
# 22                         7               0                     0   9.352701
# 23                         7               0                     0   2.094000
# 24                         7               0                     0   9.771286
# 25                         7               0                     0   0.136538
# 26                         7               0                     0   0.160500
# 27                         7               0                     0   0.047987
# 28                         7               0                     0   0.046506
# 29                         7               0                     0   0.046500
# ...                      ...             ...                   ...        ...
# 20918                     12               1                     1   9.068705
# 20919                     12               1                     1   5.888800
# 20920                     12               1                     1   9.268781
# 20921                     12               1                     1   9.881775
# 20922                     12               1                     1   5.728629
# 20923                     12               1                     1   9.193262
# 20924                     12               1                     1  11.988990
# 20925                     12               1                     1   5.997017
# 20926                     12               1                     1   8.548594
# 20927                     12               1                     1   9.134566
# 20928                     12               1                     1   6.198745
# 20929                     12               1                     1   8.724150
# 20930                     12               1                     1   5.771375
# 20931                     12               1                     1   8.639650
# 20932                     12               1                     1   9.159739
# 20933                     12               1                     1   5.955511
# 20934                     12               1                     1   8.162100
# 20935                     12               1                     1   8.606127
# 20936                     12               1                     1   5.848068
# 20937                     12               1                     1  10.057950
# 20938                     12               1                     1  10.577290
# 20939                     12               1                     1   5.854843
# 20940                     12               1                     1  12.054425
# 20941                     12               1                     1   9.377799
# 20942                     12               1                     1   5.746200
# 20943                     12               1                     1   8.698371
# 20944                     12               1                     1   9.076475
# 20945                     12               1                     1   6.417975
# 20946                     12               1                     1  10.176788
# 20947                     12               1                     1   5.764103
#
#        dayMonth
# 0            14
# 1            14
# 2            14
# 3            14
# 4            14
# 5            14
# 6            14
# 7            14
# 8            14
# 9            14
# 10           14
# 11           14
# 12           14
# 13           14
# 14           14
# 15           14
# 16           14
# 17           14
# 18           14
# 19           14
# 20           14
# 21           14
# 22           14
# 23           14
# 24           14
# 25           14
# 26           15
# 27           15
# 28           15
# 29           15
# ...         ...
# 20918        21
# 20919        21
# 20920        21
# 20921        21
# 20922        21
# 20923        21
# 20924        21
# 20925        22
# 20926        22
# 20927        22
# 20928        22
# 20929        22
# 20930        22
# 20931        22
# 20932        22
# 20933        22
# 20934        22
# 20935        22
# 20936        22
# 20937        22
# 20938        22
# 20939        22
# 20940        22
# 20941        22
# 20942        22
# 20943        22
# 20944        22
# 20945        23
# 20946        23
# 20947        23
#
# [20948 rows x 35 columns]

# %%
max(df.fecha)
# Out:
# Timestamp('2019-06-03 19:56:55')

# %%
min(df.fecha)
# Out:
# Timestamp('2019-04-04 06:02:05')

# %%
df.set_index("fecha", inplace = True)

# %%
df = df[df.index.dayofweek < 4]

# %%
Series = []
count = 0
missing_count = 0

for n,g in df.groupby(["medidor", df.index.day, df.index.month]):
    #g.set_index("fecha", inplace = True)

    g = g.resample("2h").mean()
    #g.dropna(inplace = True)
    #print(g.isna().sum().sum()
    date = (g.index.date[0])

    idx = pd.date_range(date, periods=12, freq='2H')
    #print(idx)
    s = pd.Series(np.nan, index = idx)
    s = s.loc[(s.index.hour >= 6) & (s.index.hour <= 18)]
    #print(s)
    g = g["kwh_consumido"]
    g = g.add(s, fill_value = 0)
    g = g.interpolate(method = "time", limit_direction = "both")
    
    
    #g.fillna(method = "bfill", inplace = True)
    #print(g)

    Series.append(g)
    #print(str(n) + ":   " + str(min(g.index.hour)) +"--" + str(max(g.index.hour)) +"  Tamaño: " + str(len(g)) + " indice: " + str(count))
    if (g.isnull().sum() != 0):
        print(count)
    count +=1

# %%
count = 0 
for i in Series:
    if (i.isnull().sum() >2):
        print(count)
    count += 1

# %%
Series[37]
# Out:
# 2019-05-19 06:00:00     0.876
# 2019-05-19 08:00:00     0.876
# 2019-05-19 10:00:00     0.876
# 2019-05-19 12:00:00     0.876
# 2019-05-19 14:00:00     9.429
# 2019-05-19 16:00:00     9.279
# 2019-05-19 18:00:00    13.266
# Freq: 2H, dtype: float64

# %%
Series[37].interpolate(method = "time", limit_direction = "both")
# Out:
# 2019-05-19 06:00:00     0.876
# 2019-05-19 08:00:00     0.876
# 2019-05-19 10:00:00     0.876
# 2019-05-19 12:00:00     0.876
# 2019-05-19 14:00:00     9.429
# 2019-05-19 16:00:00     9.279
# 2019-05-19 18:00:00    13.266
# Freq: 2H, dtype: float64

# %%
time_series = Series
#time_series = [i.reset_index()["kwh_consumido"] for i in Series]

# %%
'''
for i in range(len(time_series)):
    s = time_series[i]
    s = (s - s.min()) / (s.max() - s.min())
    time_series[i] = s
'''
# Out:
# '\nfor i in range(len(time_series)):\n    s = time_series[i]\n    s = (s - s.min()) / (s.max() - s.min())\n    time_series[i] = s\n'

# %%
'''
idx = pd.date_range('2019-05-19', periods=12, freq='H')
s = pd.Series(np.nan, index = idx)
Series[37]["kwh_consumido"].add(s, fill_value = 0).loc[Series[37]["kwh_consumido"].add(s, fill_value = 0).index.hour > 9]
'''
# Out:
# '\nidx = pd.date_range(\'2019-05-19\', periods=12, freq=\'H\')\ns = pd.Series(np.nan, index = idx)\nSeries[37]["kwh_consumido"].add(s, fill_value = 0).loc[Series[37]["kwh_consumido"].add(s, fill_value = 0).index.hour > 9]\n'

# %%
Series[1].reset_index()[0]
# Out:
# 0     0.357
# 1     0.108
# 2     0.102
# 3     1.935
# 4     0.801
# 5     2.916
# 6    17.988
# Name: 0, dtype: float64

# %%
import random
def k_means_clust(data,num_clust,num_iter,w=5):
    centroids=random.sample(list(data),num_clust)
    #print("Centroids")
    #print(centroids)
    counter=0
    for n in range(num_iter):
        counter+=1
        #print( counter)
        assignments={}
        #assign data points to clusters
        
        for ind,i in enumerate(data):
            min_dist=float('inf')
            closest_clust=None
            for c_ind,j in enumerate(centroids):
                #print("Iteracion#: {}, data {}, centroid: {}".format(n,ind,c_ind))
                if LB_Keogh(i,j,w)<min_dist:
                    cur_dist=DTWDistance(i,j,w)
                    if cur_dist<min_dist:
                        min_dist=cur_dist
                        closest_clust=c_ind
            if closest_clust in assignments:
                assignments[closest_clust].append(ind)
            else:
                assignments[closest_clust]=[]
    
        #recalculate centroids of clusters
        #print("recalculating centroids of clusters")
        for key in assignments:
            clust_sum=0
            for k in assignments[key]:
                u = data[k].reset_index()[0]
                clust_sum=clust_sum + u
            centroids[key]=[m/len(assignments[key]) for m in clust_sum]
    
    return centroids, assignments

# %%
def distance(centroids, indicesSeries, timeSeries):
    sumaI = 0
    countI = 0
    for c in range(len(centroids)):
        suma = 0
        count = 0
        cent = centroids[c]
        indices = indicesSeries[c]
        for i in indices:
            s = timeSeries[i]
            suma += DTWDistance(cent,s,5)
            count += 1
        suma = suma / count
        sumaI += suma
        countI +=1
    sumaI /= countI
    return sumaI

# %%
def sse(centroids, indicesSeries, timeSeries):
    sumaI = 0
    countI = 0
    for c in range(len(centroids)):
        suma = 0
        count = 0
        cent = centroids[c]
        indices = indicesSeries[c]
        for i in indices:
            s = timeSeries[i]
            suma += DTWDistance(cent,s,5)**2
            count += 1
        #suma = suma / count
        sumaI += suma
        countI +=1
    #sumaI /= countI
    return sumaI

# %%
distances = []
for n in range(1,10):
    centroids, indicesTimeSeries = k_means_clust(time_series,n,5,3)
    d = sse(centroids,indicesTimeSeries, time_series )
    distances.append(d)

# %%
fig = plt.figure()
plt.plot(distances)
fig.savefig("./clusters/mejor_n/Primer_Clusters")

# %% [markdown]
# **Recordar que el eje x debe desplazarse una unidad**
# El mejor numero de cluster es 4

# %%
n_clusters = 4
centroids2, los_demas = k_means_clust(time_series,n_clusters,5,2)
for i in centroids2:
    
    plt.plot(i)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5dc7185e14a1> in <module>
#       1 n_clusters = 4
# ----> 2 centroids2, los_demas = k_means_clust(time_series,n_clusters,5,2)
#       3 for i in centroids2:
#       4
#       5     plt.plot(i)
#
# NameError: name 'time_series' is not defined

# %%
fig = plt.figure(figsize = (15,10))

for key in ([6]):
    indexes = los_demas[key].copy()
    if(key == 0):
        c = "b"
    elif(key == 1):
        c = "g"
    elif(key == 2):
        c = "r"
    elif(key == 3):
        c = "c"
    else:
        c = "m"
    for i in indexes[:4]:
        serie2 = time_series[i].copy()
        serie2.index = serie2.index.hour 
        #serie2 = (serie2 - serie2.min() )/(serie2.max() - serie2.min())
        serie2 = (serie2 - serie2.mean() )/(serie2.std())
        serie2.plot(c = c, title = "Kwh_consumido vs horas del dia")

# %%
los_demas.keys()
# Out:
# dict_keys([1, 3, 0, 2])

# %%
new_clusters = []

# %%
new_dict = {}
fig = plt.figure()
for key in (los_demas):
    print("para la llave: " +  str(key))
    
    cluster_indexes = los_demas[key]
    new_serie = []
    for i in cluster_indexes:
        new_serie.append(time_series[i])
    distances2 = []
    for n in range(1,8):
        centroids, indicesTimeSeries = k_means_clust(new_serie,n,5,3)
        d = sse(centroids,indicesTimeSeries, new_serie )
        distances2.append(d)
    print("finalizo " + str(key) + "s")
    fig = plt.figure()
    plt.plot(distances2)
    fig.savefig("./clusters/mejor_n/" + str(key))
    #c, w = k_means_clust(new_serie,4,5,2)
    #new_dict[key] = [new_serie, c, w]
    #fig = plt.figure()
    #plt.title = "From Cluster # " + str(key)
    #for i in c:
        
        #plt.plot(i)

        #plt.show()
# Out:
# para la llave: 1
# finalizo 1s
# para la llave: 3

# %% [markdown]
# **Recordar desplazar el eje de las x dos unidades**

# %%
alto_voltaje = new_dict[2]
medio_voltaje = new_dict[3]
bajo_voltaje = new_dict[1]
muy_bajo = new_dict[0]

# %%
fig = plt.figure(figsize = (15,10))
ts = alto_voltaje[0]
for key in (alto_voltaje[2]):
        if(key == 1):

            indexes = alto_voltaje[2][key].copy()
            if(key == 0):
                c = "b"
            elif(key == 1):
                c = "g"
            elif(key == 2):
                c = "r"
            elif(key == 3):
                c = "c"
            else:
                c = "m"
            for i in indexes[:100]:
                serie = ts[i].copy()
                serie.index = serie.index.hour
                #serie = (serie - serie.min() )/(serie.max() - serie.min())
                plt.plot(serie, c = c)

# %%
fig = plt.figure(figsize = (15,10))
ts = medio_voltaje[0]
ks = medio_voltaje[2]
for key in (ks):
    
    indexes = ks[3]
    if(key == 0):
        c = "b"
    elif(key == 1):
        c = "g"
    elif(key == 2):
        c = "r"
    elif(key == 3):
        c = "c"
    else:
        c = "m"
    for i in indexes[:3]:
        serie = ts[i]
        
        serie = (serie - serie.mean()) / (serie.max() - serie.min())
        
        #serie = (serie - serie.min() )/(serie.max() - serie.min())
        plt.plot(serie, c = c)
